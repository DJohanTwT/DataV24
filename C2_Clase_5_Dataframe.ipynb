# %% [markdown]
# <a href="https://colab.research.google.com/github/DJohanTwT/DataV24/blob/main/C2_Clase_5_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. Libraries**

# %%
import numpy as np          # Algebraic operations
import pandas as pd         # Manage the data base
import plotly.express as px # Graphics

# %% [markdown]
# # **1. Import the dataset**

# %%
# Save the file path
p = '/content/data.xlsx'

# Read and save the dataset
d = pd.read_excel(p)

# %% [markdown]
# # **2. Basic Dataframe exploration**

# %%
# General info
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1519 entries, 0 to 1518
# Data columns (total 10 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Country Name                                                              1519 non-null   object
#  1   Country Code                                                              1519 non-null   object
#  2   Time                                                                      1519 non-null   int64
#  3   Time Code                                                                 1519 non-null   object
#  4   Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]                 1519 non-null   object
#  5   Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]                 1519 non-null   object
# ...

# %%
# View the first 5 rows
d.head()
# Out:
#   Country Name Country Code  Time Time Code  \
# 0  Afghanistan          AFG  2017    YR2017
# 1  Afghanistan          AFG  2018    YR2018
# 2  Afghanistan          AFG  2019    YR2019
# 3  Afghanistan          AFG  2020    YR2020
# 4  Afghanistan          AFG  2021    YR2021
#
#   Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                          10.420817
# 4                                          14.342153
#
#   Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                          36.289077
# 4                                          37.069564
#
# ...

# %%
# View the last 5 rows
d.tail()
# Out:
#      Country Name Country Code  Time Time Code  \
# 1514     Zimbabwe          ZWE  2019    YR2019
# 1515     Zimbabwe          ZWE  2020    YR2020
# 1516     Zimbabwe          ZWE  2021    YR2021
# 1517     Zimbabwe          ZWE  2022    YR2022
# 1518     Zimbabwe          ZWE  2023    YR2023
#
#      Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]  \
# 1514                                          27.554156
# 1515                                          22.293063
# 1516                                          22.775241
# 1517                                          27.955246
# 1518                                                 ..
#
#      Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]  \
# 1514                                          28.241805
# 1515                                          25.020302
# 1516                                          28.071888
# 1517                                          37.001395
# ...

# %% [markdown]
# # **3. Cleaning**

# %% [markdown]
# ## 3.1. Column names

# %%
# Time to year
d.rename(columns={'Time': 'year'}, inplace=True)

# Country name to country
d.rename(columns={'Country Name': 'country'}, inplace=True)

# Country code to code
d.rename(columns={'Country Code': 'code'}, inplace=True)

# Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS] to exports
d.rename(columns={'Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]': 'exports'}, inplace=True)

# Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS] to imports
d.rename(columns={'Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]': 'imports'}, inplace=True)

# Foreign direct investment, net inflows (% of GDP) [BX.KLT.DINV.WD.GD.ZS] to fdi
d.rename(columns={'Foreign direct investment, net inflows (% of GDP) [BX.KLT.DINV.WD.GD.ZS]': 'fdi'}, inplace=True)

# Trade (% of GDP) [NE.TRD.GNFS.ZS] to trade
d.rename(columns={'Trade (% of GDP) [NE.TRD.GNFS.ZS]': 'trade'}, inplace=True)

# GDP growth (annual %) [NY.GDP.MKTP.KD.ZG] to gdp_grow
d.rename(columns={'GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]': 'gdp_grow'}, inplace=True)

# External balance on goods and services (% of GDP) [NE.RSB.GNFS.ZS] to trade_balance
d.rename(columns={'External balance on goods and services (% of GDP) [NE.RSB.GNFS.ZS]': 'balance'}, inplace=True)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1519 entries, 0 to 1518
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1519 non-null   object
#  1   code       1519 non-null   object
#  2   year       1519 non-null   int64
#  3   Time Code  1519 non-null   object
#  4   exports    1519 non-null   object
#  5   imports    1519 non-null   object
#  6   fdi        1519 non-null   object
#  7   trade      1519 non-null   object
#  8   gdp_grow   1519 non-null   object
#  9   balance    1519 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 118.8+ KB

# %% [markdown]
# ##3.1.1. Duplicate Dataset

# %%
# Duplicate the dataset - It is done because things are going to be deleted and to avoid problems.
d2 = d

# %% [markdown]
# ## 3.1.2. Create a new column with year as string

# %%
# Create a new colum with yeas as str
d2['year_str'] = d2['year'].astype(str)
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1519 entries, 0 to 1518
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1519 non-null   object
#  1   code       1519 non-null   object
#  2   year       1519 non-null   int64
#  3   Time Code  1519 non-null   object
#  4   exports    1519 non-null   object
#  5   imports    1519 non-null   object
#  6   fdi        1519 non-null   object
#  7   trade      1519 non-null   object
#  8   gdp_grow   1519 non-null   object
#  9   balance    1519 non-null   object
#  10  year_str   1519 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 130.7+ KB

# %% [markdown]
# ## 3.2. Delete columns (Time code)

# %%
d2 = d2.drop(columns=['Time Code']) # It runs once, not two or more times because it gives an error.
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1519 entries, 0 to 1518
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   1519 non-null   object
#  1   code      1519 non-null   object
#  2   year      1519 non-null   int64
#  3   exports   1519 non-null   object
#  4   imports   1519 non-null   object
#  5   fdi       1519 non-null   object
#  6   trade     1519 non-null   object
#  7   gdp_grow  1519 non-null   object
#  8   balance   1519 non-null   object
#  9   year_str  1519 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 118.8+ KB

# %% [markdown]
# ## 3.3. Delete NaN

# %%
# Replace by NaN
d2 = d2.replace('..', np.nan)
d2.head()
# Out:
# <ipython-input-11-9b19c7240b5e>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d2 = d2.replace('..', np.nan)
#        country code  year    exports    imports       fdi      trade  \
# 0  Afghanistan  AFG  2017        NaN        NaN  0.274797        NaN
# 1  Afghanistan  AFG  2018        NaN        NaN  0.661572        NaN
# 2  Afghanistan  AFG  2019        NaN        NaN  0.124496        NaN
# 3  Afghanistan  AFG  2020  10.420817  36.289077  0.064994  46.709895
# 4  Afghanistan  AFG  2021  14.342153  37.069564  0.144401  51.411716
#
#     gdp_grow    balance year_str
# 0   2.647003        NaN     2017
# 1   1.189228        NaN     2018
# 2   3.911603        NaN     2019
# 3  -2.351101 -25.868260     2020
# 4 -20.738839 -22.727411     2021

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1519 entries, 0 to 1518
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   1519 non-null   object
#  1   code      1519 non-null   object
#  2   year      1519 non-null   int64
#  3   exports   1220 non-null   float64
#  4   imports   1220 non-null   float64
#  5   fdi       1150 non-null   float64
#  6   trade     1220 non-null   float64
#  7   gdp_grow  1433 non-null   float64
#  8   balance   1220 non-null   float64
#  9   year_str  1519 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 118.8+ KB

# %%
# Drop NaN
d2 = d2.dropna() #will take the entire line of NaN and erase it, thus reducing the base
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1008 entries, 3 to 1517
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   1008 non-null   object
#  1   code      1008 non-null   object
#  2   year      1008 non-null   int64
#  3   exports   1008 non-null   float64
#  4   imports   1008 non-null   float64
#  5   fdi       1008 non-null   float64
#  6   trade     1008 non-null   float64
#  7   gdp_grow  1008 non-null   float64
#  8   balance   1008 non-null   float64
#  9   year_str  1008 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 86.6+ KB

# %% [markdown]
# # **4. Indexing**
# We tell Python that it is not just information that is put in, but that there are relationships.

# %% [markdown]
# Categories of the dataset

# %%
# Indexing
d2 = d2.set_index(['year', 'country'])
d2.head()
# Out:
#                  code    exports    imports       fdi      trade   gdp_grow  \
# year country
# 2020 Afghanistan  AFG  10.420817  36.289077  0.064994  46.709895  -2.351101
# 2021 Afghanistan  AFG  14.342153  37.069564  0.144401  51.411716 -20.738839
# 2017 Albania      ALB  31.569798  46.624451  7.855448  78.194250   3.802599
# 2018 Albania      ALB  31.571954  45.236230  7.946356  76.808184   4.019346
# 2019 Albania      ALB  31.304270  44.974925  7.797920  76.279195   2.087712
#
#                     balance year_str
# year country
# 2020 Afghanistan -25.868260     2020
# 2021 Afghanistan -22.727411     2021
# 2017 Albania     -15.054653     2017
# 2018 Albania     -13.664275     2018
# 2019 Albania     -13.670655     2019

# %%
d2.info() #country and year do not appear as selectable columns, because they are at the top. The more categories you have to index, the better. The more data you index, the better graphs you can make.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1008 entries, (2020, 'Afghanistan') to (2022, 'Zimbabwe')
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   code      1008 non-null   object
#  1   exports   1008 non-null   float64
#  2   imports   1008 non-null   float64
#  3   fdi       1008 non-null   float64
#  4   trade     1008 non-null   float64
#  5   gdp_grow  1008 non-null   float64
#  6   balance   1008 non-null   float64
#  7   year_str  1008 non-null   object
# dtypes: float64(6), object(2)
# memory usage: 71.7+ KB

# %% [markdown]
# # **5. Descriptive statistics**

# %%
# Basic
d2.describe() #only get the descriptive statistics of the variables that are numbers
# Out:
#            exports      imports          fdi        trade     gdp_grow  \
# count  1008.000000  1008.000000  1008.000000  1008.000000  1008.000000
# mean     42.541756    47.748240     3.563746    90.289996     2.586084
# std      32.247551    28.042078    18.800117    58.115182     7.395210
# min       1.571162     1.127673  -394.471644     2.698834   -54.335876
# 25%      22.775003    29.067187     1.069240    55.699663     0.884286
# 50%      35.084904    41.640886     2.557996    77.078758     3.154638
# 75%      51.147141    58.787271     4.511036   105.564017     5.299660
# max     213.222679   198.445418   234.248695   402.459681   153.492641
#
#            balance
# count  1008.000000
# mean     -5.206485
# std      16.587675
# min     -86.617105
# 25%     -12.815523
# 50%      -2.714714
# 75%       2.902563
# max      50.709722

# %%
d2.describe().apply(lambda s: s.apply('{0:.2f}'.format)) #.2 means that python is being asked for 2 decimal places
# Out:
#        exports  imports      fdi    trade gdp_grow  balance
# count  1008.00  1008.00  1008.00  1008.00  1008.00  1008.00
# mean     42.54    47.75     3.56    90.29     2.59    -5.21
# std      32.25    28.04    18.80    58.12     7.40    16.59
# min       1.57     1.13  -394.47     2.70   -54.34   -86.62
# 25%      22.78    29.07     1.07    55.70     0.88   -12.82
# 50%      35.08    41.64     2.56    77.08     3.15    -2.71
# 75%      51.15    58.79     4.51   105.56     5.30     2.90
# max     213.22   198.45   234.25   402.46   153.49    50.71

# %%
d2.describe().apply(lambda s: s.apply('{:,.2f}'.format)) #with a coma.
# Out:
#         exports   imports       fdi     trade  gdp_grow   balance
# count  1,008.00  1,008.00  1,008.00  1,008.00  1,008.00  1,008.00
# mean      42.54     47.75      3.56     90.29      2.59     -5.21
# std       32.25     28.04     18.80     58.12      7.40     16.59
# min        1.57      1.13   -394.47      2.70    -54.34    -86.62
# 25%       22.78     29.07      1.07     55.70      0.88    -12.82
# 50%       35.08     41.64      2.56     77.08      3.15     -2.71
# 75%       51.15     58.79      4.51    105.56      5.30      2.90
# max      213.22    198.45    234.25    402.46    153.49     50.71

# %% [markdown]
# # **6. Filters and subset**

# %% [markdown]
# ## **6.1. Filters**

# %%
# Filter for data from France
france_data = d2[d2['code'] == 'FRA']
france_data
# Out:
#              code    exports    imports       fdi      trade  gdp_grow  \
# year country
# 2017 France   FRA  30.948633  32.013214  1.382120  62.961847  2.291420
# 2018 France   FRA  31.713667  32.724285  2.776578  64.437953  1.865066
# 2019 France   FRA  31.592055  32.549418  1.960494  64.141473  1.842972
# 2020 France   FRA  27.327736  29.454421  0.731612  56.782157 -7.540459
# 2021 France   FRA  30.034994  31.917320  3.239382  61.952314  6.435210
# 2022 France   FRA  34.686400  38.563453  3.793503  73.249853  2.454758
#
#                balance year_str
# year country
# 2017 France  -1.064581     2017
# 2018 France  -1.010618     2018
# 2019 France  -0.957362     2019
# 2020 France  -2.126686     2020
# 2021 France  -1.882325     2021
# 2022 France  -3.877053     2022

# %%
# another way
d2[d2['exports'] >= 200].head() #paises con exportaciones mayores a 200%
# Out:
#                           code     exports     imports         fdi  \
# year country
# 2021 Hong Kong SAR, China  HKG  204.014264  198.445418   37.183819
# 2019 Luxembourg            LUX  206.411650  175.936719  234.248695
# 2020 Luxembourg            LUX  203.120263  169.151140   13.350022
# 2021 Luxembourg            LUX  213.222679  179.918519   29.354272
# 2022 Luxembourg            LUX  211.278206  177.235463 -394.471644
#
#                                 trade  gdp_grow    balance year_str
# year country
# 2021 Hong Kong SAR, China  402.459681  6.454397   5.568846     2021
# 2019 Luxembourg            382.348369  2.915848  30.474930     2019
# 2020 Luxembourg            372.271403 -0.909830  33.969124     2020
# 2021 Luxembourg            393.141198  7.168402  33.304159     2021
# 2022 Luxembourg            388.513668  1.380186  34.042743     2022

# %%
# Filters for data from multiple countries
latam = ['Colombia', 'Mexico', 'Peru', 'Brazil', 'Chile']
latam_data = d2[d2.index.get_level_values('country').isin(latam)]
latam_data.head()
# Out:
#              code    exports    imports       fdi      trade  gdp_grow  \
# year country
# 2017 Brazil   BRA  12.518968  11.800767  3.338260  24.319734  1.322869
# 2018 Brazil   BRA  14.634999  14.241204  4.077487  28.876203  1.783667
# 2019 Brazil   BRA  14.122919  14.767339  3.692673  28.890258  1.220778
# 2020 Brazil   BRA  16.453552  15.848527  2.592638  32.302079 -3.276759
# 2021 Brazil   BRA  19.109430  18.546900  2.779791  37.656331  4.762604
#
#                balance year_str
# year country
# 2017 Brazil   0.718201     2017
# 2018 Brazil   0.393796     2018
# 2019 Brazil  -0.644419     2019
# 2020 Brazil   0.605025     2020
# 2021 Brazil   0.562530     2021

# %% [markdown]
# ## **6.2. Pivots**

# %%
pivot_table_balance = pd.pivot_table(
    d2[
        (d2.index.get_level_values("year") >= 2017)
        & (d2.index.get_level_values("year") <= 2023)
    ],
    values="fdi",
    index="country",
    aggfunc="mean",
)

pivot_table_balance
# Out:
#                            fdi
# country
# Afghanistan           0.104698
# Albania               7.511786
# Algeria               0.551566
# Angola               -6.777075
# Antigua and Barbuda  11.933603
# ...                        ...
# Viet Nam              4.670793
# West Bank and Gaza    1.147591
# Yemen, Rep.          -1.155479
# Zambia                1.849406
# Zimbabwe              1.303248
#
# [174 rows x 1 columns]

# %% [markdown]
# ## **6.3. Graphs**

# %% [markdown]
# ### **6.3.1. Bar Chart**

# %%
# !apt-get update
# !apt-get install chromium-browser
import os

os.environ["BROWSER_PATH"] = "/usr/bin/chromium-browser"  # Replace with the actual path to your Chrome/Chromium executable

import pandas as pd
import plotly.express as px

# Assuming d2 is your DataFrame...

pivot_table_balance = pd.pivot_table(
    d2[
        (d2.index.get_level_values("year") >= 2017)
        & (d2.index.get_level_values("year") <= 2023)
    ],
    values="fdi",
    index="country",
    aggfunc="mean",
)

# Create a bar chart
fig = px.bar(
    pivot_table_balance,  # Use the pivot table as the data source
    x=pivot_table_balance.index,  # Country names on the x-axis
    y="fdi",  # Use 'fdi' instead of 'balance' for the y-axis
    title="Average FDI by Country (2017-2023)",  # Update the title to reflect FDI
    labels={"fdi": "Average FDI"},  # Update the label for the y-axis
)
fig.show()
# Out:
# Hit:1 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# ...

# %% [markdown]
# ### **6.3.2. Heatmap Chart**

# %%
## With Russia

# !pip install --upgrade plotly

# Lista de países de Europa occidental
western_europe_countries = ["Brazil", "Russian Federation", "India", "China", "South Africa"]


# Filtrar datos para países de Europa occidental
western_europe_data = d2[d2.index.get_level_values("country").isin(western_europe_countries)]


# Crear una tabla dinámica para el mapa de calor
heatmap_data = pd.pivot_table(
   western_europe_data, values="balance", index="country", columns="year"
)


# Función para interpolar colores entre rojo, blanco y verde
def custom_color_scale(value):
   if value < 0:
       # Rojo con intensidad según la magnitud del déficit
       intensity = min(1, abs(value) / 10)  # Ajusta 10 según el rango de valores
       return f"rgba(255, 0, 0, {intensity})"
   elif value == 0:
       # Blanco para cero
       return "rgb(255, 255, 255)"
   else:
       # Verde con intensidad según la magnitud del superávit
       intensity = min(1, value / 10)  # Ajusta 10 según el rango de valores
       return f"rgba(0, 255, 0, {intensity})"


# Crear una lista de colores para la escala de color continua
num_colors = 100  # Ajusta el número de colores según la precisión deseada
color_scale = [
   [i / num_colors, custom_color_scale(heatmap_data.values.min() + i / num_colors * (heatmap_data.values.max() - heatmap_data.values.min()))]
   for i in range(num_colors + 1)
]


# Crear el mapa de calor con escala de color personalizada
fig = px.imshow(
   heatmap_data,
   labels=dict(x="Year", y="Country", color="Trade Balance"),
   x=heatmap_data.columns,
   y=heatmap_data.index,
   color_continuous_scale=color_scale,
)


# Agregar valores a los cuadrantes
fig.update_traces(
   text=heatmap_data.values.round(2),  # Redondear a 2 decimales
   texttemplate="<i>%{text}</i>",  # Formato en itálica con HTML
   textfont=dict(family="Open Sans", size=14, color="black") # Fuente Times New Roman
)


# Personalizar la apariencia
fig.update_layout(
   title="<b>TRADE BALANCE HEATMAP FOR BRICS COUNTRIES</b>",
   title_x=0.5,  # Centrar el título
   title_font=dict(family="Times New Roman", size=18, color="Red"),  # Fuente del título
   font=dict(family="Times New Roman", size=16, color="black")  # Fuente general del gráfico
)


# Mostrar el mapa de calor
fig.show()
# Out:
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - <font color = "Blue" face = "Times New Roman" size = "5"> Analysis 1 </font>
#
# <font color = "black" face = "Times New Roman" size = "4"> According to the heatmap, among the countries that are part of the BRICS. India is the country with the largest trade deficit since throughout the years between 2017 and 2022, it has imported more than it has exported and Russia is the country with the largest surplus above China and South Africa, since it has exported more than the other countries. Brazil is the country that is the most balanced, as it is close to zero, although it has had a slightly positive trade balance. Thus, among these countries, Russia depends on its exports of oil, natural gas, minerals, wheat and grains; and India depends on its imports of gold, chemicals, pharmaceuticals and agricultural products. </font>

# %% [markdown]
# # **7. Data Visualization**

# %% [markdown]
# ## **7.1. Line chart**

# %%
colombia_data = d2[d2.index.get_level_values('country') == 'Colombia']

fig = px.line(colombia_data,
              x=colombia_data.index.get_level_values('year'),
              y='gdp_grow',
              title='FIGURE 2. GDP GROWTH IN COLOMBIA (2017 - 2022)')

fig.update_layout(
    title_font_family="Times New Roman",
    title_font_size=24,  # Increased title font size
    title_font_color="red",
    title_x=0.5,
    xaxis_title="Year",
    yaxis_title="GDP Growth (annual %)",
    xaxis_title_font_family="Times New Roman",
    yaxis_title_font_family="Times New Roman",
    xaxis_title_font_style="italic",
    yaxis_title_font_style="italic",
    xaxis_title_font_size=20,  # Increased x-axis title font size
    yaxis_title_font_size=20,  # Increased y-axis title font size
    font_family="Times New Roman",
    font_size=16,  # Increased overall font size
    plot_bgcolor="white",
    xaxis=dict(tickfont_size=16),  # Increased x-axis tick font size
    yaxis=dict(tickfont_size=16)   # Increased y-axis tick font size
)

fig.update_traces(
    line=dict(width=4),
    mode="lines+markers+text",
    marker=dict(size=10, color="orange"),
    text=colombia_data['gdp_grow'].map('{:.2f}'.format),  # Format data labels to 2 decimal places
    textposition="top center",
    textfont_size=14  # Increased data label font size
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - <font color = "Blue" face = "Times New Roman" size = "5"> Analysis 2 </font>
#
# <font color = "black" face = "Times New Roman" size = "4"> As seen in the line graph, moderate economic growth was identified from 2017 to 2019, but there was a severe contraction in 2020 due to the pandemic, an extraordinary recovery in 2021, and a slowdown in 2022. Before the pandemic GDP growth was steady, but since the confinement the Colombian economy was affected and so in 2020 there was a decrease. This means that major events affecting the global economy have a greater impact on Colombia and Latin or developing countries. </font>

# %% [markdown]
# ## **7.2. More than one line**

# %%
import plotly.express as px
import plotly.graph_objects as go

# List of countries to include in the graph
north_america_countries = ['Canada', 'Mexico', 'United States']

# Define el diccionario de colores
colors = {'Canada': 'red', 'United States': 'blue', 'Mexico': 'green'}

# Filter data for the selected countries
filtered_data = d2[d2.index.get_level_values('country').isin(north_america_countries)]

# Create an empty figure
fig = go.Figure()

# Add a trace for each country
for country in north_america_countries:
    country_data = filtered_data[filtered_data.index.get_level_values('country') == country]
    fig.add_trace(go.Scatter(
        x=country_data.index.get_level_values('year'),
        y=country_data['fdi'],
        mode='lines+markers+text',
        name=country,
        line=dict(color=colors[country], width=3),
        marker=dict(size=8),
        text=country_data['fdi'].map('{:.2f}'.format),
        textposition='top center',
        textfont_size=16
    ))

# Update layout
fig.update_layout(
    title='FIGURE 3. FDI OF NORTH AMERICA COUNTRIES (2017 - 2022)',
    title_font_family="Times New Roman",
    title_font_size=24,
    title_font_color="red",
    title_x=0.5,
    xaxis_title="Year",
    yaxis_title="FDI (% of GDP)",
    xaxis_title_font_family="Times New Roman",
    yaxis_title_font_family="Times New Roman",
    xaxis_title_font_style="italic",
    yaxis_title_font_style="italic",
    font_family="Times New Roman",
    plot_bgcolor="white",
    legend_font_family="Arial Narrow",
    legend_borderwidth=1,
    legend_bordercolor="black",
    legend_title_font_family="Arial Narrow",
    xaxis=dict(tickfont_size=16),
    yaxis=dict(tickfont_size=16)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# - <font color = "Blue" face = "Times New Roman" size = "5"> Analysis 3 </font>
#
# <font color = "black" face = "Times New Roman" size = "4"> According to the multi-line graph, it can be seen that, throughout these years, Mexico and Canada have maintained relatively high and stable FDI levels compared to the United States. This comparison suggests that Mexico and Canada have had greater stability in attracting FDI relative to GDP, while the United States has shown greater variability and a more recent increase in 2022. </font>

# %% [markdown]
# ## **7.3. Animated the graph**

# %% [markdown]
# ## 7.3.1. South America Trade Map

# %%
# !pip install -U kaleido --no-cache-dir

# %%
import plotly.express as px
import imageio
import os
import kaleido
import pandas as pd

# %%
south_america_countries = ["Argentina", "Bolivia", "Brazil", "Chile", "Colombia", "Ecuador",
                          "Guyana", "Paraguay", "Peru", "Suriname", "Uruguay", "Venezuela, RB"]

filtered_data = d2[
   (d2.index.get_level_values('year') >= 2017)  # Ajusta el rango de años si lo deseas
   & (d2.index.get_level_values('year') <= 2022)
   & (d2.index.get_level_values('country').isin(south_america_countries))
]

trade_by_year = filtered_data.groupby(['year', 'code', 'country'])['trade'].mean().reset_index()

# %%
frames = []
for year in range(2017, 2023):
    year_data = trade_by_year[trade_by_year['year'] == year]
    fig = px.choropleth(
        year_data,
        locations="code",
        color="trade",
        hover_name="country",
        color_continuous_scale="Viridis",  # Puedes cambiar la escala de colores
        animation_frame="year",
        title=f"Trade (% of GDP) of South America ({year})",
        range_color=[trade_by_year['trade'].min(), trade_by_year['trade'].max()],
        scope="south america"
    )

    # Guardar el frame como una imagen PNG en un directorio temporal
    if not os.path.exists('frames_trade'):
        os.makedirs('frames_trade')
    frame_path = os.path.join('frames_trade', f'frame_{year}.png')
    fig.write_image(frame_path)

    # Agregar el frame a la lista
    frames.append(imageio.imread(frame_path))

# Guardar la lista de frames como un GIF
imageio.mimsave('trade_south_america.gif', frames, fps=1)
# Out:
# <ipython-input-30-cb122e6287c9>:23: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#
# <ipython-input-30-cb122e6287c9>:23: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#
# <ipython-input-30-cb122e6287c9>:23: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#
# <ipython-input-30-cb122e6287c9>:23: DeprecationWarning:
#
# ...

# %% [markdown]
# ## 7.3.2. South America Trade Map Better

# %%
import plotly.express as px
import imageio
import os
import kaleido
import pandas as pd
import plotly.graph_objs as go


# Definir la lista de países de Sur América
south_america_countries = ["Argentina", "Bolivia", "Brazil", "Chile", "Colombia", "Ecuador",
                          "Guyana", "Paraguay", "Peru", "Suriname", "Uruguay", "Venezuela, RB"]


# Filtrar los datos
filtered_data = d2[
   (d2.index.get_level_values('year') >= 2017)
   & (d2.index.get_level_values('year') <= 2022)
   & (d2.index.get_level_values('country').isin(south_america_countries))
]


fdi_by_year = filtered_data.groupby(['year', 'code', 'country'])['trade'].mean().reset_index()


# Crear un directorio temporal para almacenar los frames
if not os.path.exists('frames_tradegdp'):
   os.makedirs('frames_tradegdp')


for year in range(2017, 2023):
   year_data = fdi_by_year[fdi_by_year['year'] == year]
   fig = px.choropleth(
       year_data,
       locations="code",
       color="trade",
       hover_name="country",
       color_continuous_scale="RdBu",
       animation_frame="year",
       title=f"TRADE (%. of GDP) IN SOUTH AMERICA {year}",
       range_color=[fdi_by_year['trade'].min(), fdi_by_year['trade'].max()],
       scope="south america"
   )


   # Crear anotación con la lista de países y FDI (con formato HTML)
   text_annotation = "<br>".join([f"<b>{row['country']}:</b> {row['trade']:.2f}%" for i, row in year_data.iterrows()])


   fig.update_layout(
       annotations=[
           dict(
               x=0,
               y=0.5,
               text=text_annotation,
               showarrow=False,
               font=dict(size=12, color="blue"),
               xanchor='left',
               yanchor='middle',
               align="left"
           ),
           dict(
               x=0.95,
               y=0.95,
               text=str(year),
               showarrow=False,
               font=dict(size=16, color="black"),
               xanchor='right',
               yanchor='top'
           )
       ],
       coloraxis_colorbar=dict(
           title="Trade (% of GDP)",
           ticksuffix="%"
       ),
       title=dict(
           text=f"<b>TRADE (% OF GDP) IN SOUTH AMERICA</b>",
           x=0.5,
           font=dict(
               family="Times New Roman",
               size=20,
               color="Brown"
           )
       )
   )


   # Guardar el frame como una imagen PNG
   frame_path = os.path.join('frames_tradegdp', f'frame_{year}.png')
   fig.write_image(frame_path)


# Cargar los frames en una lista
frames = []
for year in range(2017, 2023):
   frame_path = os.path.join('frames_tradegdp', f'frame_{year}.png')
   frames.append(imageio.imread(frame_path))


# Guardar la lista de frames como un GIF
imageio.mimsave('tradegdp_south_america.gif', frames, fps=1)
# Out:
# <ipython-input-31-1967347b008a>:96: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
