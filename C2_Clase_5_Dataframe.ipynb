# %% [markdown]
# <a href="https://colab.research.google.com/github/DJohanTwT/DataV24/blob/main/C2_Clase_5_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **0. Libraries**

# %%
import numpy as np          # Algebraic operations
import pandas as pd         # Manage the data base
import plotly.express as px # Graphics

# %% [markdown]
# # **1. Import the dataset**

# %%
# Save the file path
p = '/content/data.xlsx'

# Read and save the dataset
d = pd.read_excel(p)

# %% [markdown]
# # **2. Basic Dataframe exploration**

# %%
# General info
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1519 entries, 0 to 1518
# Data columns (total 10 columns):
#  #   Column                                                                    Non-Null Count  Dtype
# ---  ------                                                                    --------------  -----
#  0   Country Name                                                              1519 non-null   object
#  1   Country Code                                                              1519 non-null   object
#  2   Time                                                                      1519 non-null   int64
#  3   Time Code                                                                 1519 non-null   object
#  4   Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]                 1519 non-null   object
#  5   Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]                 1519 non-null   object
# ...

# %%
# View the first 5 rows
d.head()
# Out:
#   Country Name Country Code  Time Time Code  \
# 0  Afghanistan          AFG  2017    YR2017
# 1  Afghanistan          AFG  2018    YR2018
# 2  Afghanistan          AFG  2019    YR2019
# 3  Afghanistan          AFG  2020    YR2020
# 4  Afghanistan          AFG  2021    YR2021
#
#   Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                          10.420817
# 4                                          14.342153
#
#   Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]  \
# 0                                                 ..
# 1                                                 ..
# 2                                                 ..
# 3                                          36.289077
# 4                                          37.069564
#
# ...

# %%
# View the last 5 rows
d.tail()
# Out:
#      Country Name Country Code  Time Time Code  \
# 1514     Zimbabwe          ZWE  2019    YR2019
# 1515     Zimbabwe          ZWE  2020    YR2020
# 1516     Zimbabwe          ZWE  2021    YR2021
# 1517     Zimbabwe          ZWE  2022    YR2022
# 1518     Zimbabwe          ZWE  2023    YR2023
#
#      Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]  \
# 1514                                          27.554156
# 1515                                          22.293063
# 1516                                          22.775241
# 1517                                          27.955246
# 1518                                                 ..
#
#      Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]  \
# 1514                                          28.241805
# 1515                                          25.020302
# 1516                                          28.071888
# 1517                                          37.001395
# ...

# %% [markdown]
# # **3. Cleaning**

# %% [markdown]
# ## 3.1. Column names

# %%
# Time to year
d.rename(columns={'Time': 'year'}, inplace=True)

# Country name to country
d.rename(columns={'Country Name': 'country'}, inplace=True)

# Country code to code
d.rename(columns={'Country Code': 'code'}, inplace=True)

# Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS] to exports
d.rename(columns={'Exports of goods and services (% of GDP) [NE.EXP.GNFS.ZS]': 'exports'}, inplace=True)

# Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS] to imports
d.rename(columns={'Imports of goods and services (% of GDP) [NE.IMP.GNFS.ZS]': 'imports'}, inplace=True)

# Foreign direct investment, net inflows (% of GDP) [BX.KLT.DINV.WD.GD.ZS] to fdi
d.rename(columns={'Foreign direct investment, net inflows (% of GDP) [BX.KLT.DINV.WD.GD.ZS]': 'fdi'}, inplace=True)

# Trade (% of GDP) [NE.TRD.GNFS.ZS] to trade
d.rename(columns={'Trade (% of GDP) [NE.TRD.GNFS.ZS]': 'trade'}, inplace=True)

# GDP growth (annual %) [NY.GDP.MKTP.KD.ZG] to gdp_grow
d.rename(columns={'GDP growth (annual %) [NY.GDP.MKTP.KD.ZG]': 'gdp_grow'}, inplace=True)

# External balance on goods and services (% of GDP) [NE.RSB.GNFS.ZS] to trade_balance
d.rename(columns={'External balance on goods and services (% of GDP) [NE.RSB.GNFS.ZS]': 'balance'}, inplace=True)

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1519 entries, 0 to 1518
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1519 non-null   object
#  1   code       1519 non-null   object
#  2   year       1519 non-null   int64
#  3   Time Code  1519 non-null   object
#  4   exports    1519 non-null   object
#  5   imports    1519 non-null   object
#  6   fdi        1519 non-null   object
#  7   trade      1519 non-null   object
#  8   gdp_grow   1519 non-null   object
#  9   balance    1519 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 118.8+ KB

# %% [markdown]
# ##3.1.1. Duplicate Dataset

# %%
# Duplicate the dataset - It is done because things are going to be deleted and to avoid problems.
d2 = d

# %% [markdown]
# ## 3.1.2. Create a new column with year as string

# %%
# Create a new colum with yeas as str
d2['year_str'] = d2['year'].astype(str)
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1519 entries, 0 to 1518
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1519 non-null   object
#  1   code       1519 non-null   object
#  2   year       1519 non-null   int64
#  3   Time Code  1519 non-null   object
#  4   exports    1519 non-null   object
#  5   imports    1519 non-null   object
#  6   fdi        1519 non-null   object
#  7   trade      1519 non-null   object
#  8   gdp_grow   1519 non-null   object
#  9   balance    1519 non-null   object
#  10  year_str   1519 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 130.7+ KB

# %% [markdown]
# ## 3.2. Delete columns (Time code)

# %%
d2 = d2.drop(columns=['Time Code']) # It runs once, not two or more times because it gives an error.
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1519 entries, 0 to 1518
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   1519 non-null   object
#  1   code      1519 non-null   object
#  2   year      1519 non-null   int64
#  3   exports   1519 non-null   object
#  4   imports   1519 non-null   object
#  5   fdi       1519 non-null   object
#  6   trade     1519 non-null   object
#  7   gdp_grow  1519 non-null   object
#  8   balance   1519 non-null   object
#  9   year_str  1519 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 118.8+ KB

# %% [markdown]
# ## 3.3. Delete NaN

# %%
# Replace by NaN
d2 = d2.replace('..', np.nan)
d2.head()
# Out:
# <ipython-input-11-9b19c7240b5e>:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   d2 = d2.replace('..', np.nan)
#        country code  year    exports    imports       fdi      trade  \
# 0  Afghanistan  AFG  2017        NaN        NaN  0.274797        NaN
# 1  Afghanistan  AFG  2018        NaN        NaN  0.661572        NaN
# 2  Afghanistan  AFG  2019        NaN        NaN  0.124496        NaN
# 3  Afghanistan  AFG  2020  10.420817  36.289077  0.064994  46.709895
# 4  Afghanistan  AFG  2021  14.342153  37.069564  0.144401  51.411716
#
#     gdp_grow    balance year_str
# 0   2.647003        NaN     2017
# 1   1.189228        NaN     2018
# 2   3.911603        NaN     2019
# 3  -2.351101 -25.868260     2020
# 4 -20.738839 -22.727411     2021

# %%
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1519 entries, 0 to 1518
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   1519 non-null   object
#  1   code      1519 non-null   object
#  2   year      1519 non-null   int64
#  3   exports   1220 non-null   float64
#  4   imports   1220 non-null   float64
#  5   fdi       1150 non-null   float64
#  6   trade     1220 non-null   float64
#  7   gdp_grow  1433 non-null   float64
#  8   balance   1220 non-null   float64
#  9   year_str  1519 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 118.8+ KB

# %%
# Drop NaN
d2 = d2.dropna() #will take the entire line of NaN and erase it, thus reducing the base
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1008 entries, 3 to 1517
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   country   1008 non-null   object
#  1   code      1008 non-null   object
#  2   year      1008 non-null   int64
#  3   exports   1008 non-null   float64
#  4   imports   1008 non-null   float64
#  5   fdi       1008 non-null   float64
#  6   trade     1008 non-null   float64
#  7   gdp_grow  1008 non-null   float64
#  8   balance   1008 non-null   float64
#  9   year_str  1008 non-null   object
# dtypes: float64(6), int64(1), object(3)
# memory usage: 86.6+ KB

# %% [markdown]
# # **4. Indexing**
# We tell Python that it is not just information that is put in, but that there are relationships.

# %% [markdown]
# Categories of the dataset

# %%
# Indexing
d2 = d2.set_index(['year', 'country'])
d2.head()
# Out:
#                  code    exports    imports       fdi      trade   gdp_grow  \
# year country
# 2020 Afghanistan  AFG  10.420817  36.289077  0.064994  46.709895  -2.351101
# 2021 Afghanistan  AFG  14.342153  37.069564  0.144401  51.411716 -20.738839
# 2017 Albania      ALB  31.569798  46.624451  7.855448  78.194250   3.802599
# 2018 Albania      ALB  31.571954  45.236230  7.946356  76.808184   4.019346
# 2019 Albania      ALB  31.304270  44.974925  7.797920  76.279195   2.087712
#
#                     balance year_str
# year country
# 2020 Afghanistan -25.868260     2020
# 2021 Afghanistan -22.727411     2021
# 2017 Albania     -15.054653     2017
# 2018 Albania     -13.664275     2018
# 2019 Albania     -13.670655     2019

# %%
d2.info() #country and year do not appear as selectable columns, because they are at the top. The more categories you have to index, the better. The more data you index, the better graphs you can make.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1008 entries, (2020, 'Afghanistan') to (2022, 'Zimbabwe')
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   code      1008 non-null   object
#  1   exports   1008 non-null   float64
#  2   imports   1008 non-null   float64
#  3   fdi       1008 non-null   float64
#  4   trade     1008 non-null   float64
#  5   gdp_grow  1008 non-null   float64
#  6   balance   1008 non-null   float64
#  7   year_str  1008 non-null   object
# dtypes: float64(6), object(2)
# memory usage: 71.7+ KB

# %% [markdown]
# # **5. Descriptive statistics**

# %%
# Basic
d2.describe() #only get the descriptive statistics of the variables that are numbers
# Out:
#            exports      imports          fdi        trade     gdp_grow  \
# count  1008.000000  1008.000000  1008.000000  1008.000000  1008.000000
# mean     42.541756    47.748240     3.563746    90.289996     2.586084
# std      32.247551    28.042078    18.800117    58.115182     7.395210
# min       1.571162     1.127673  -394.471644     2.698834   -54.335876
# 25%      22.775003    29.067187     1.069240    55.699663     0.884286
# 50%      35.084904    41.640886     2.557996    77.078758     3.154638
# 75%      51.147141    58.787271     4.511036   105.564017     5.299660
# max     213.222679   198.445418   234.248695   402.459681   153.492641
#
#            balance
# count  1008.000000
# mean     -5.206485
# std      16.587675
# min     -86.617105
# 25%     -12.815523
# 50%      -2.714714
# 75%       2.902563
# max      50.709722

# %%
d2.describe().apply(lambda s: s.apply('{0:.2f}'.format)) #.2 means that python is being asked for 2 decimal places
# Out:
#        exports  imports      fdi    trade gdp_grow  balance
# count  1008.00  1008.00  1008.00  1008.00  1008.00  1008.00
# mean     42.54    47.75     3.56    90.29     2.59    -5.21
# std      32.25    28.04    18.80    58.12     7.40    16.59
# min       1.57     1.13  -394.47     2.70   -54.34   -86.62
# 25%      22.78    29.07     1.07    55.70     0.88   -12.82
# 50%      35.08    41.64     2.56    77.08     3.15    -2.71
# 75%      51.15    58.79     4.51   105.56     5.30     2.90
# max     213.22   198.45   234.25   402.46   153.49    50.71

# %%
d2.describe().apply(lambda s: s.apply('{:,.2f}'.format)) #with a coma.
# Out:
#         exports   imports       fdi     trade  gdp_grow   balance
# count  1,008.00  1,008.00  1,008.00  1,008.00  1,008.00  1,008.00
# mean      42.54     47.75      3.56     90.29      2.59     -5.21
# std       32.25     28.04     18.80     58.12      7.40     16.59
# min        1.57      1.13   -394.47      2.70    -54.34    -86.62
# 25%       22.78     29.07      1.07     55.70      0.88    -12.82
# 50%       35.08     41.64      2.56     77.08      3.15     -2.71
# 75%       51.15     58.79      4.51    105.56      5.30      2.90
# max      213.22    198.45    234.25    402.46    153.49     50.71

# %% [markdown]
# ## **6. Filters and subset**

# %%
# Foñter for data from Argentina
colombia_data = d2[d2['code'] == 'COL']
colombia_data
# Out:
#               code    exports    imports       fdi      trade   gdp_grow  \
# year country
# 2017 Colombia  COL  15.145290  20.137625  4.393182  35.282915   1.359361
# 2018 Colombia  COL  15.899720  20.635033  3.380836  36.534753   2.564324
# 2019 Colombia  COL  15.868039  21.690495  4.330582  37.558534   3.186855
# 2020 Colombia  COL  13.522276  20.533295  2.758894  34.055571  -7.185914
# 2021 Colombia  COL  16.197006  23.862140  3.001757  40.059146  10.801198
# 2022 Colombia  COL  20.232400  27.841577  4.975683  48.073978   7.288884
#
#                 balance year_str
# year country
# 2017 Colombia -4.992335     2017
# 2018 Colombia -4.735313     2018
# 2019 Colombia -5.822457     2019
# 2020 Colombia -7.011020     2020
# 2021 Colombia -7.665134     2021
# 2022 Colombia -7.609177     2022

# %%
# another way
d2[d2['exports'] >= 100].head() #paises con exportaciones mayores a 100%
# Out:
#               code     exports     imports       fdi       trade  gdp_grow  \
# year country
# 2017 Djibouti  DJI  150.098361  155.869605  5.970136  305.967966  5.458092
# 2018 Djibouti  DJI  156.619875  143.778812  5.834973  300.398687  4.774417
# 2019 Djibouti  DJI  166.717746  154.221257  5.665500  320.939003  5.545131
# 2020 Djibouti  DJI  115.626523  107.211460  4.967740  222.837983  1.316363
# 2021 Djibouti  DJI  143.022084  120.998169  4.924948  264.020254  4.522348
#
#                  balance year_str
# year country
# 2017 Djibouti  -5.771243     2017
# 2018 Djibouti  12.841063     2018
# 2019 Djibouti  12.496490     2019
# 2020 Djibouti   8.415064     2020
# 2021 Djibouti  22.023915     2021

# %%
# Filters for data from multiple countries
latam = ['Colombia', 'Mexico', 'Peru', 'Brazil', 'Chile']
latam_data = d2[d2.index.get_level_values('country').isin(latam)]
latam_data.head()
# Out:
#              code    exports    imports       fdi      trade  gdp_grow  \
# year country
# 2017 Brazil   BRA  12.518968  11.800767  3.338260  24.319734  1.322869
# 2018 Brazil   BRA  14.634999  14.241204  4.077487  28.876203  1.783667
# 2019 Brazil   BRA  14.122919  14.767339  3.692673  28.890258  1.220778
# 2020 Brazil   BRA  16.453552  15.848527  2.592638  32.302079 -3.276759
# 2021 Brazil   BRA  19.109430  18.546900  2.779791  37.656331  4.762604
#
#                balance year_str
# year country
# 2017 Brazil   0.718201     2017
# 2018 Brazil   0.393796     2018
# 2019 Brazil  -0.644419     2019
# 2020 Brazil   0.605025     2020
# 2021 Brazil   0.562530     2021

# %% [markdown]
# ## **6.2. Pivots**

# %%
pivot_table_balance = pd.pivot_table(
    d2[
        (d2.index.get_level_values("year") >= 2018)
        & (d2.index.get_level_values("year") <= 2022)
    ],
    values="balance",
    index="country",
    aggfunc="mean",
)
# Execute the code yourself to see the output

pivot_table_balance
# Out:
#                        balance
# country
# Afghanistan         -24.297836
# Albania             -13.121515
# Algeria              -1.810730
# Angola               17.971967
# Antigua and Barbuda  -6.170517
# ...                        ...
# Viet Nam              4.033917
# West Bank and Gaza  -39.585249
# Yemen, Rep.         -41.391085
# Zambia                9.011098
# Zimbabwe             -3.996002
#
# [174 rows x 1 columns]

# %%
# Create a bar chart
fig = px.bar(
    pivot_table_balance,  # Use the pivot table as the data source
    x=pivot_table_balance.index,  # Country names on the x-axis
    y="balance",  # Average trade balance on the y-axis
    title="Average Trade Balance by Country (2018-2022)",  # Set the title
    labels={"balance": "Average Trade Balance"},  # Label for the y-axis
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a pivot table for the heatmap
heatmap_data = pd.pivot_table(
    d2, values="balance", index="country", columns="year"
)

# Create the heatmap
fig = px.imshow(
    heatmap_data,  # Data for the heatmap
    labels=dict(x="Year", y="Country", color="Trade Balance"),  # Axis labels
    x=heatmap_data.columns,  # Year values on the x-axis
    y=heatmap_data.index,  # Country names on the y-axis
    color_continuous_scale="RdBu",  # Red-Blue color scale
)

# Customize the appearance
fig.update_layout(title="Trade Balance Heatmap for All Countries")

# Show the heatmap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# Create a pivot table for the heatmap
heatmap_data = pd.pivot_table(d2, values="balance", index="country", columns="year")

# Create the heatmap with custom color scale
fig = px.imshow(
    heatmap_data,
    labels=dict(x="Year", y="Country", color="Trade Balance"),
    x=heatmap_data.columns,
    y=heatmap_data.index,
    color_continuous_scale=[
        [0, "red"],  # Deficit (red)
        [0.5, "white"],  # Neutral (white)
        [1, "green"],  # Surplus (green)
    ],
)

# Customize the appearance
fig.update_layout(title="Trade Balance Heatmap for All Countries")

# Show the heatmap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import plotly.express as px

# List of South American countries
south_america_countries = [
    "Argentina",
    "Bolivia",
    "Brazil",
    "Chile",
    "Colombia",
    "Ecuador",
    "Guyana",
    "Paraguay",
    "Peru",
    "Suriname",
    "Uruguay",
    "Venezuela, RB",
]

# Filter data for South American countries
south_america_data = d2[d2.index.get_level_values("country").isin(south_america_countries)]

# Create a pivot table for the heatmap
heatmap_data = pd.pivot_table(
    south_america_data, values="balance", index="country", columns="year"
)

# Create the heatmap with custom color scale
fig = px.imshow(
    heatmap_data,
    labels=dict(x="Year", y="Country", color="Trade Balance"),
    x=heatmap_data.columns,
    y=heatmap_data.index,
    color_continuous_scale=[
        [0, "red"],  # Deficit (red)
        [0.5, "white"],  # Neutral (white)
        [1, "green"],  # Surplus (green)
    ],
)

# Customize the appearance
fig.update_layout(title="Trade Balance Heatmap for South American Countries")

# Show the heatmap
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **7. Data Visualization**

# %% [markdown]
# ## **7.1. Line chart**

# %%
colombia_data = d2[d2.index.get_level_values('country') == 'Colombia']

import plotly.express as px

fig = px.line(colombia_data, x=colombia_data.index.get_level_values('year'), y='gdp_grow',
              title='GDP Growth of Colombia Over Time')
fig.update_layout(xaxis_title="Year", yaxis_title="GDP Growth (annual %)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## **7.2. More than one line"

# %%
import plotly.express as px

# List of countries to include in the graph
countries = ['Colombia', 'Brazil', 'Bolivia', 'Argentina', 'Chile', 'Ecuador', 'Peru', 'Paraguay', 'Uruguay']

# Filter data for the selected countries
filtered_data = d2[d2.index.get_level_values('country').isin(countries)]

# Create the line graph
fig = px.line(filtered_data,
              x=filtered_data.index.get_level_values('year'),
              y='exports',
              color=filtered_data.index.get_level_values('country'),  # Color lines by country
              title='Exports of South American Countries Over Time')

fig.update_layout(xaxis_title="Year", yaxis_title="Exports (% of GDP)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## 7.3. Animated the graph

# %%
# !pip install plotly kaleido imageio

# %%
import plotly.express as px
import imageio
import os
import kaleido

# %%
# Create a temporary directory to store frames if it doesn't exist
if not os.path.exists('frames'):
    os.makedirs('frames')

# Generate and save frames
countries = ['Colombia', 'Brazil', 'Bolivia', 'Argentina', 'Chile', 'Ecuador', 'Peru', 'Paraguay', 'Uruguay']
years = filtered_data.index.get_level_values('year').unique()  # Get unique years
num_frames = len(years)

for i, year in enumerate(years):
    # Filter data for current year
    frame_data = filtered_data[filtered_data.index.get_level_values('year') <= year]

    # Create the line graph for the current frame
    fig = px.line(frame_data,
                  x=frame_data.index.get_level_values('year'),
                  y='exports',
                  color=frame_data.index.get_level_values('country'),
                  title=f'Exports of South American Countries Over Time (Year: {year})')

    fig.update_layout(xaxis_title="Year", yaxis_title="Exports (% of GDP)")

    # Save the frame as a PNG image
    frame_path = os.path.join('frames', f'frame_{i:04d}.png')  # Pad frame number with zeros
    fig.write_image(frame_path)

# %%
# Create the GIF from the saved frames
frames = []
for i in range(num_frames):
    frame_path = os.path.join('frames', f'frame_{i:04d}.png')
    frames.append(imageio.imread(frame_path))

imageio.mimsave('exports_animation.gif', frames, fps=5)  # Adjust fps for animation speed
# Out:
# <ipython-input-43-399653ff1324>:5: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.

# %%
import plotly.express as px
import imageio
import os
import kaleido

# Create a temporary directory to store frames if it doesn't exist
if not os.path.exists('frames'):
    os.makedirs('frames')

# Filter data for years 2017-2022
filtered_data = filtered_data[
    (filtered_data.index.get_level_values('year') >= 2017)
    & (filtered_data.index.get_level_values('year') <= 2022)
]

# Get unique years within the filtered data
years = filtered_data.index.get_level_values('year').unique()
num_frames = len(years)

# Generate and save frames
for i, year in enumerate(years):
    frame_data = filtered_data[filtered_data.index.get_level_values('year') <= year]

    fig = px.line(
        frame_data,
        x=frame_data.index.get_level_values('year'),
        y='exports',
        color=frame_data.index.get_level_values('country'),
        title=f'Exports of South American Countries Over Time (Year: {year})',
    )

    fig.update_layout(xaxis_title="Year", yaxis_title="Exports (% of GDP)")

    frame_path = os.path.join('frames', f'frame_{i:04d}.png')
    fig.write_image(frame_path)

# Create the GIF from the saved frames
frames = []
for i in range(num_frames):
    frame_path = os.path.join('frames', f'frame_{i:04d}.png')
    frames.append(imageio.imread(frame_path))

imageio.mimsave('exports(1fps)_animation.gif', frames, fps=1)  # Reduced fps for smoother animation with fewer years
# Out:
# <ipython-input-48-3ab969109135>:41: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.

# %%
import plotly.express as px
import imageio
import os
import kaleido
import pandas as pd

# Create a temporary directory to store frames
if not os.path.exists('frames'):
    os.makedirs('frames')

# List of South American countries
south_america_countries = [
    "Argentina",
    "Bolivia",
    "Brazil",
    "Chile",
    "Colombia",
    "Ecuador",
    "Guyana",
    "Paraguay",
    "Peru",
    "Suriname",
    "Uruguay",
    "Venezuela, RB",
]

# Filter data for the desired years and South American countries
filtered_data = d2[
    (d2.index.get_level_values('year') >= 2017)
    & (d2.index.get_level_values('year') <= 2022)
    & (d2.index.get_level_values('country').isin(south_america_countries))
]
years = filtered_data.index.get_level_values('year').unique()

# Generate and save frames for each year
for i, year in enumerate(years):
    # Filter data for the current year and South American countries
    year_data = filtered_data[filtered_data.index.get_level_values('year') == year]

    # Create a pivot table for the heatmap (using filtered data)
    heatmap_data = pd.pivot_table(year_data, values="balance", index="country", columns=["year"])

    # Create the heatmap
    fig = px.imshow(
        heatmap_data,
        labels=dict(x="Year", y="Country", color="Trade Balance"),
        x=heatmap_data.columns,
        y=heatmap_data.index,
        color_continuous_scale=[
            [0, "red"],  # Deficit (red)
            [0.5, "white"],  # Neutral (white)
            [1, "green"],  # Surplus (green)
        ],
        title=f"Trade Balance Heatmap for South America (Year: {year})"  # Updated title
    )

    # Save the frame as a PNG image
    frame_path = os.path.join('frames', f'frame_{i:04d}.png')
    fig.write_image(frame_path)

# Create the GIF from the saved frames
frames = []
for i in range(len(years)):
    frame_path = os.path.join('frames', f'frame_{i:04d}.png')
    frames.append(imageio.imread(frame_path))

imageio.mimsave('heatmap_animation_south_america.gif', frames, fps=2)  # Adjust fps as needed
# Out:
# <ipython-input-51-d7b4207e10e9>:65: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.

# %%
import plotly.express as px
import imageio
import os
import kaleido
import pandas as pd

# Create a temporary directory to store frames
if not os.path.exists('frames'):
    os.makedirs('frames')

# Filter data for the desired years (adjust if needed)
filtered_data = d2[
    (d2.index.get_level_values('year') >= 2017)
    & (d2.index.get_level_values('year') <= 2022)
]
years = filtered_data.index.get_level_values('year').unique()

# Generate and save frames for each year
for i, year in enumerate(years):
    # Filter data for the current year and **all previous years** to show the progression
    year_data = filtered_data[filtered_data.index.get_level_values('year') <= year]

    # Reset the index to make 'year' a column
    year_data = year_data.reset_index()

    # Merge with country code data (replace with your actual data)
    # Assuming you have a DataFrame called 'country_codes' with 'country' and 'code' columns
    # year_data = pd.merge(year_data, country_codes, on='country', how='left')

    # Create the choropleth map
    fig = px.choropleth_mapbox(
        year_data,
        geojson="https://raw.githubusercontent.com/python-visualization/folium/master/examples/data/world-countries.json", # GeoJSON data for world map
        locations='code',  # Country codes column
        featureidkey="properties.name",  # Key in GeoJSON to match locations
        color='balance',  # Column to use for color encoding
        color_continuous_scale=[
            [0, "red"],  # Deficit (red)
            [0.5, "white"],  # Neutral (white)
            [1, "green"],  # Surplus (green)
        ],
        mapbox_style="carto-positron",  # Mapbox style
        zoom=0.5,  # Initial zoom level
        center={"lat": 20, "lon": 0},  # Center of the map
        opacity=0.7,  # Opacity of the choropleth layer
        title=f"Trade Balance Map (Year: {year})",  # Update title with year
        animation_frame="year",  # Specify the animation frame
    )

    fig.update_layout(margin={"r": 0, "t": 30, "l": 0, "b": 0})  # Adjust margins

    # Save the frame as a PNG image
    frame_path = os.path.join('frames', f'frame_{i:04d}.png')
    fig.write_image(frame_path)


# Create the GIF from the saved frames
frames = []
for i in range(len(years)):
    frame_path = os.path.join('frames', f'frame_{i:04d}.png')
    frames.append(imageio.imread(frame_path))

imageio.mimsave('trade_balance_map_animation.gif', frames, fps=2)  # Adjust fps as needed
# Out:
# <ipython-input-54-7933f62e7f63>:61: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.

# %%
# !pip install plotly geopandas mapbox
import plotly.express as px
import imageio
import os
import kaleido
import pandas as pd
import geopandas as gpd  # Import geopandas

# Create a temporary directory to store frames
if not os.path.exists('frames'):
    os.makedirs('frames')

# Filter data for the desired years (adjust if needed)
filtered_data = d2[
    (d2.index.get_level_values('year') >= 2017)
    & (d2.index.get_level_values('year') <= 2022)
]
years = filtered_data.index.get_level_values('year').unique()

# Load South America GeoJSON data
south_america_geojson = gpd.read_file("https://raw.githubusercontent.com/johan/world.geo.json/master/countries/ARG.geo.json") # Replace with a valid South America GeoJSON URL if needed

# Generate and save frames for each year
for i, year in enumerate(years):
    # Filter data for the current year and all previous years
    year_data = filtered_data[filtered_data.index.get_level_values('year') <= year]

    # Reset the index to make 'year' a column
    year_data = year_data.reset_index()

    # Merge with country code data (replace with your actual data)
    # Assuming you have a DataFrame called 'country_codes' with 'country' and 'code' columns
    # year_data = pd.merge(year_data, country_codes, on='country', how='left')

    # Create the choropleth map for South America
    fig = px.choropleth_mapbox(
        year_data,
        geojson=south_america_geojson,  # Use South America GeoJSON
        locations='code',  # Country codes column - **Make sure this matches your data**
        featureidkey="properties.id",  # Key in GeoJSON to match locations (adjust if needed)
        color='balance',  # Column to use for color encoding
        color_continuous_scale=[
            [0, "red"],  # Deficit (red)
            [0.5, "white"],  # Neutral (white)
            [1, "green"],  # Surplus (green)
        ],
        mapbox_style="carto-positron",  # Mapbox style
        zoom=2,  # Adjust zoom for South America
        center={"lat": -15, "lon": -60},  # Center on South America
        opacity=0.7,  # Opacity of the choropleth layer
        title=f"Trade Balance Map (Year: {year})",  # Update title with year
        animation_frame="year",  # Specify the animation frame
    )

    fig.update_layout(margin={"r": 0, "t": 30, "l": 0, "b": 0})  # Adjust margins

    # Save the frame as a PNG image
    frame_path = os.path.join('frames', f'frame_{i:04d}.png')
    fig.write_image(frame_path)

# Create the GIF from the saved frames
frames = []
for i in range(len(years)):
    frame_path = os.path.join('frames', f'frame_{i:04d}.png')
    frames.append(imageio.imread(frame_path))

imageio.mimsave('trade_balance_map_animation_south_america.gif', frames, fps=2)  # Adjust fps as needed
# Out:
# ...
# <ipython-input-55-1122fb88b388>:65: DeprecationWarning:
#
# Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
